# %%
# selenuim을 사용해보자!
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://search.naver.com/search.naver?where=nexearch&query=2023%EB%85%84+%EB%B0%95%EC%8A%A4%EC%98%A4%ED%94%BC%EC%8A%A4+%EC%88%9C%EC%9C%84&ie=utf8&sm=tab_she&qdt=0')
time.sleep(10)
chartDiv=driver.find_element(By.CLASS_NAME,'movie_audience_ranking')

# %%
content_list=chartDiv.find_element(By.CLASS_NAME,'_content')

# %%
li_list=content_list.find_element(By.TAG_NAME,'li')

# %%
movie_info=li_list.find_element(By.CLASS_NAME,'movie_info')

# %%
a_tag=movie_info.find_element(By.CLASS_NAME,'movie_tit')
#링크

# %%
movie_title=a_tag.find_element(By.CLASS_NAME,'scm_ellipsis_text ')
#영화제목

# %%
movie_item=li_list.find_element(By.CLASS_NAME,'movie_item')

# %%
movie_date=movie_item.find_element(By.TAG_NAME,'dd')
#개봉일

# %%
content_list.text
# Out:
# '15세 관람가\n1\n범죄도시3\n개봉\n2023.05.31.\n누적\n10,682,702명\n예매 예고편\n전체 관람가\n2\n엘리멘탈\n개봉\n2023.06.14.\n누적\n7,208,375명\n예매 예고편\n12세 관람가\n3\n스즈메의 문단속\n개봉\n2023.03.08.\n누적\n5,549,628명\n예매 예고편\n15세 관람가\n4\n밀수\n개봉\n2023.07.26.\n누적\n5,136,970명\n예매 예고편\n12세 관람가\n5\n더 퍼스트 슬램덩크\n개봉\n2023.01.04.\n누적\n4,749,624명\n예매 예고편\n12세 관람가\n6\n가디언즈 오브 갤럭시: Volume 3\n개봉\n2023.05.03.\n누적\n4,208,994명\n예고편\n15세 관람가\n7\n미션 임파서블: 데드 레코닝 PA...\n개봉\n2023.07.12.\n누적\n4,021,563명\n예매 예고편\n15세 관람가\n8\n콘크리트 유토피아\n개봉\n2023.08.09.\n누적\n3,822,944명\n예매 예고편'

# %%
# selenuim을 사용해보자!
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://search.naver.com/search.naver?where=nexearch&query=2023%EB%85%84+%EB%B0%95%EC%8A%A4%EC%98%A4%ED%94%BC%EC%8A%A4+%EC%88%9C%EC%9C%84&ie=utf8&sm=tab_she&qdt=0')
time.sleep(10)
chartDiv=driver.find_element(By.CLASS_NAME,'movie_audience_ranking')

# test_dic={}

# content_list=chartDiv.find_element(By.CLASS_NAME,'_content')
# li_list=content_list.find_element(By.TAG_NAME,'li')

# for li in li_list:
#     movie_info=li_list.find_element(By.CLASS_NAME,'movie_info') #여기가 다른네 나는 list에서 돌고 chatGPT는 각 li에서 돌고
#     a_tag=movie_info.find_element(By.CLASS_NAME,'movie_tit') #링크
#     movie_title=a_tag.find_element(By.CLASS_NAME,'scm_ellipsis_text')#영화제목
#     movie_item=li_list.find_element(By.CLASS_NAME,'movie_item')
#     movie_date=movie_item.find_element(By.TAG_NAME,'dd')#개봉일
#     key=movie_title
#     value = movie_date
#     test_dic[key]=value

# chatGPT 수정ver 잘됨
# test_dic = {}

# content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
# li_list = content_list.find_elements(By.TAG_NAME, 'li')  # find_elements를 사용하여 모든 li 요소를 가져옵니다.

# for li in li_list:
#     movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
#     a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  # 링크
#     movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
#     movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
#     movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일
#     key = movie_title.text  # .text를 사용하여 텍스트 내용을 가져옵니다.
#     value = movie_date.text
#     test_dic[key] = value

# 영화 이름만 값으로 들어가는게 아니라 영화이름과 개봉일 둘다 들어가는 코드
test_dic = {}

content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
li_list = content_list.find_elements(By.TAG_NAME, 'li')  # find_elements를 사용하여 모든 li 요소를 가져옵니다.

for li in li_list:
    movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
    a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  # 링크
    movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
    movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
    movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일
    
    title = movie_title.text
    date = movie_date.text
    value = f'{title} ({date})'  # 영화 제목과 개봉일을 합친 문자열을 생성
    
    key = title  # 영화 제목을 key로 사용
    test_dic[key] = value  # 딕셔너리에 추가

# %%
#위에서 2023년 데꼬와지는지는 확인함. 잘됨.

#다음. 2023년 영화순위와 2022년, 2021년의 차이는?

#https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84
# =뒤에 년도가 다름.
#=> url도는 함수는 따로 만들고 그 url을 driver.get부분에 넣으면 됨.

# 1.url 작업

# %%
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = split1[0] + '=' + split1[1] + '=' + split1[2] + '=' + split1[3] + chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    change_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ change_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}

url=url_list[0]

# 각 페이지별 딕셔너리 초기화
test_dic = {}

    # 페이지 로딩
driver.get(url)
time.sleep(10)

    # 페이지에서 딕셔너리 생성
chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
li_list = content_list.find_elements(By.TAG_NAME, 'li')

for li in li_list:
    movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
    a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  # 링크
    movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
    movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
    movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일

    title = movie_title.text
    date = movie_date.text
    value = f'{title} ({date})'

    test_dic[title] = value

    # 페이지별 딕셔너리를 상위 딕셔너리에 추가
    result_dic[url] = test_dic

# 상위 딕셔너리 출력
print(result_dic)
# Out:
# {'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84': {'범죄도시3': '범죄도시3 (2023.05.31.)', '엘리멘탈': '엘리멘탈 (2023.06.14.)', '스즈메의 문단속': '스즈메의 문단속 (2023.03.08.)', '밀수': '밀수 (2023.07.26.)', '더 퍼스트 슬램덩크': '더 퍼스트 슬램덩크 (2023.01.04.)', '가디언즈 오브 갤럭시: Volume 3': '가디언즈 오브 갤럭시: Volume 3 (2023.05.03.)', '미션 임파서블: 데드 레코닝 PA...': '미션 임파서블: 데드 레코닝 PA... (2023.07.12.)', '콘크리트 유토피아': '콘크리트 유토피아 (2023.08.09.)'}}

# %%
#아래의 스파이더맨으로 함을 함수로 하나 만들자.

def find_movie(test_url):
    import selenium
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.chrome.service import Service as ChromeService
    import time

    options = webdriver.ChromeOptions()
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)
    options.add_argument('headless')
    service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)

    test_dic={}
    
#     test_url='https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&pkid=68&os=23527376&qvt=0&query=%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8%3A%20%EB%85%B8%20%EC%9B%A8%EC%9D%B4%20%ED%99%88'
    driver.get(test_url)
    time.sleep(10)
    try:
        text=driver.find_element(By.CLASS_NAME,'text_expand') #
        a=text.find_element(By.TAG_NAME,'a')
        href = a.get_attribute('href')
        href

        driver.get(href)
        movie_title = driver.find_element(By.CLASS_NAME,'area_text_title')
        movie_title.text # 제목 가져옴
        ontent_text = driver.find_element(By.CLASS_NAME,'_content_text')
        content_text.text # 줄거리 가져옴
        info_group = driver.find_element(By.CLASS_NAME,'info_group')
        open_date=info_group.find_element(By.TAG_NAME,'dd')

        title = movie_title.text
        date = open_date.text
        content = content_text.text
        value = f'{content} ({date})'

        test_dic[title] = value
    except:
        print("문제 발생. 대상을 찾지못함. 넘김")
    
    return test_dic

########################################################

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}

# 각 URL에 대해 반복
for url in url_list:
    # 각 페이지별 딕셔너리 초기화
#     test_dic = {}

    # 페이지 로딩
    driver.get(url)
    time.sleep(10)

    # 페이지에서 딕셔너리 생성
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
    li_list = content_list.find_elements(By.TAG_NAME, 'li')

    for li in li_list:
        movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
        a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  # 링크
        href=a_tag.get_attribute("href")
#         movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
#         movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
#         movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일

        test_dic=find_movie(href)
    
        split1 = url.split('=')
        split2 = split1[4].split('%')
        chage_year = str(year)
        
#         title = movie_title.text
#         date = movie_date.text
#         value = f'{date} ({chage_year})'
#         value = f'{title} ({date})'
        
        
        
#         test_dic[title] = test_dic

    # 페이지별 딕셔너리를 상위 딕셔너리에 추가
    result_dic[chage_year] = test_dic

# 상위 딕셔너리 출력
print(result_dic)
# 출력 내용 : 궁금증 왜 2012년만 된것인가?
# {'2012': {'도둑들': '2012.07.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_706")>)', '광해, 왕이 된 남자': '2012.09.13. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_711")>)', '어벤져스': '2012.04.26. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_716")>)', '늑대소년': '2012.10.31. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_721")>)', '다크 나이트 라이즈': '2012.07.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_726")>)', '레미제라블': '2012.12.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_731")>)', '타워': '2012.12.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_736")>)', '바람과 함께 사라지다': '2012.08.08. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_741")>)'}}
# Out:
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# {'2012': {'바람과 함께 사라지다': '‘미스테리오’의 계략으로 세상에 정체가 탄로난 스파이더맨 ‘피터 파커’는 하루 아침에 평범한 일상을 잃게 된다. 문제를 해결하기 위해 ‘닥터 스트레인지’를 찾아가 도움을 청하지만 뜻하지 않게 멀티버스가 열리면서 각기 다른 차원의 불청객들이 나타난다. ‘닥터 옥토퍼스’를 비롯해 스파이더맨에게 깊은 원한을 가진 숙적들의 강력한 공격에 ‘피터 파커’는 사상 최악의 위기를 맞게 되는데… (2012.08.08.)'}}

# %%
result_dic
# Out:
# {'2012': {}}

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

test_url='https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&pkid=68&os=23527376&qvt=0&query=%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8%3A%20%EB%85%B8%20%EC%9B%A8%EC%9D%B4%20%ED%99%88'
driver.get(test_url)
time.sleep(10)
text=driver.find_element(By.CLASS_NAME,'text_expand')
a=text.find_element(By.TAG_NAME,'a')
href = a.get_attribute('href')
href

driver.get(href)
movie_title = driver.find_element(By.CLASS_NAME,'area_text_title')
movie_title.text # 제목 가져옴
ontent_text = driver.find_element(By.CLASS_NAME,'_content_text')
content_text.text # 줄거리 가져옴
info_group = driver.find_element(By.CLASS_NAME,'info_group')
open_date=info_group.find_element(By.TAG_NAME,'dd')

test_dic={}

title = movie_title.text
date = open_date.text
content = content_text.text
value = f'{content} ({date})'

test_dic[title] = value

print(test_dic)
# Out:
# {'스파이더맨: 노 웨이 홈': '‘미스테리오’의 계략으로 세상에 정체가 탄로난 스파이더맨 ‘피터 파커’는 하루 아침에 평범한 일상을 잃게 된다. 문제를 해결하기 위해 ‘닥터 스트레인지’를 찾아가 도움을 청하지만 뜻하지 않게 멀티버스가 열리면서 각기 다른 차원의 불청객들이 나타난다. ‘닥터 옥토퍼스’를 비롯해 스파이더맨에게 깊은 원한을 가진 숙적들의 강력한 공격에 ‘피터 파커’는 사상 최악의 위기를 맞게 되는데… (2021.12.15.)'}

# %%
# 까보기 목표!! 왜 마지막은 2012년꺼만 저장하는가?
#아래의 스파이더맨으로 함수화 

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}

# 각 URL에 대해 반복
for url in url_list:
    # 각 페이지별 딕셔너리 초기화
#     test_dic = {}

    # 페이지 로딩
    driver.get(url)
    time.sleep(10)

    # 페이지에서 딕셔너리 생성
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
    li_list = content_list.find_elements(By.TAG_NAME, 'li')

    for li in li_list:
        movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
        a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  # 링크
        href=a_tag.get_attribute("href")
        movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
        movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
        movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일

        find_movie(href)
    
        split1 = url.split('=')
        split2 = split1[4].split('%')
        chage_year = str(year)
        
        title = movie_title.text
        date = movie_date.text
        value = f'{date} ({chage_year})'
        value = f'{title} ({date})'
        
        
        
        test_dic[title] = test_dic

    # 페이지별 딕셔너리를 상위 딕셔너리에 추가
    result_dic[chage_year] = test_dic

# 상위 딕셔너리 출력
print(result_dic)
# 출력 내용 : 궁금증 왜 2012년만 된것인가?
# {'2012': {'도둑들': '2012.07.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_706")>)', '광해, 왕이 된 남자': '2012.09.13. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_711")>)', '어벤져스': '2012.04.26. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_716")>)', '늑대소년': '2012.10.31. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_721")>)', '다크 나이트 라이즈': '2012.07.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_726")>)', '레미제라블': '2012.12.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_731")>)', '타워': '2012.12.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_736")>)', '바람과 함께 사라지다': '2012.08.08. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_741")>)'}}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 42
#      36 for url in url_list:
#      37     # 각 페이지별 딕셔너리 초기화
#      38 #     test_dic = {}
#      39
#      40     # 페이지 로딩
#      41     driver.get(url)
# ---> 42     time.sleep(10)
#      44     # 페이지에서 딕셔너리 생성
#      45     chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
#
# KeyboardInterrupt:
